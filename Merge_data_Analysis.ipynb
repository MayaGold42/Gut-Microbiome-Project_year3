# %%
#Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from pathlib import Path
sns.set_theme(style="whitegrid")

# %% [markdown]
# EDA on people data

# %% [markdown]
# ## Summary
#
# This notebook profiles the dietary records and participant metadata.
#
# The analysis includes:
# - Loading daily dietary records from `nutrition_totals.txt`.
# - Selecting key dietary variables: calories (`KCAL`), fiber (`FIBE`), carbohydrates (`CARB`), and total fat (`TFAT`).
# - Calculating missing-value percentages for dietary variables.
# - Visualizing missing values using `missingno`.
# - Aggregating dietary records into average intake per participant.
# - Loading participant metadata from `food_map.txt`.
# - Adding participant-level characteristics: `Age` and `BMI`.
# - Plotting histograms and boxplots for nutrient intake and participant characteristics.
#
# These variables can later be used as control variables / confounders in downstream microbiome analysis.

# %%
# Define file paths

base_dir = Path.cwd()

#diet_dir = base_dir / "dietstudy_analyses-master" / "data" / "diet"
#maps_dir = base_dir / "dietstudy_analyses-master" / "data" / "maps"
diet_dir = base_dir / "data" / "dietstudy_analyses-master" / "data" / "diet"
maps_dir = base_dir / "data" / "dietstudy_analyses-master" / "data" / "maps"

nutrition_path = diet_dir / "nutrition_totals.txt"
metadata_path = maps_dir / "food_map.txt"

print("Nutrition path exists:", nutrition_path.exists())
print("Nutrition path:", nutrition_path)

print("Metadata path exists:", metadata_path.exists())
print("Metadata path:", metadata_path)

# print("\nFiles in maps directory:")z
# for file in maps_dir.iterdir():
#     print(file.name)
# Out:
# Nutrition path exists: True
# Nutrition path: c:\Users\mayag\PythonForuni\ProjectYear3\data\dietstudy_analyses-master\data\diet\nutrition_totals.txt
# Metadata path exists: True
# Metadata path: c:\Users\mayag\PythonForuni\ProjectYear3\data\dietstudy_analyses-master\data\maps\food_map.txt

# %%
# Load the nutrition totals data

df_nutrients = pd.read_csv(nutrition_path, sep="\t")

df_nutrients.columns = df_nutrients.columns.str.strip()

print("Nutrients shape:", df_nutrients.shape)

display(df_nutrients.head())

print("Nutrient columns:")
print(df_nutrients.columns.tolist())
# Out:
# Nutrients shape: (580, 107)
#    X.SampleID UserName StudyDayNo  RecordDayNo         KCAL        PROT  \
# 0  MCT.f.0001   MCTs01     Day.01            1  1707.040193   95.668747
# 1  MCT.f.0002   MCTs01     Day.02            2  1970.043625  109.619765
# 2  MCT.f.0003   MCTs01     Day.03            3  1714.895330   89.992993
# 3  MCT.f.0004   MCTs01     Day.04            4  2487.232625   94.611953
# 4  MCT.f.0005   MCTs01     Day.05            5  2260.211176  110.268353
#
#         TFAT        CARB         MOIS       ALC  ...  PF_LEGUMES   D_TOTAL  \
# 0  55.185318  187.965353  3848.605502  14.95872  ...         0.0  3.265577
# 1  53.615264  242.919015  3808.005721  14.04000  ...         0.0  4.156035
# 2  50.561373  234.225138  4183.622433   0.00000  ...         0.0  2.979655
# 3  92.021551  257.539030  4816.211548  42.44800  ...         0.0  3.634460
# 4  95.570253  165.608070  4404.243876  43.93060  ...         0.0  3.379710
#
#     D_MILK  D_YOGURT  D_CHEESE       OILS  SOLID_FATS  ADD_SUGARS  A_DRINKS  \
# 0  2.05776     0.646  0.561817  14.668870   21.795872    4.822350  1.072512
# 1  2.35656     0.646  1.153475  15.886225   19.139825    4.325970  1.008000
# 2  1.12608     0.646  1.207575  11.836920   17.711575    4.758330  0.000000
# 3  2.15186     0.000  1.482600  55.308100   19.937800    5.917100  3.035200
# 4  2.32071     0.000  1.059000  24.231213   54.613613    5.793898  3.116360
#
#    Replicate
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 107 columns]
# Nutrient columns:
# ['X.SampleID', 'UserName', 'StudyDayNo', 'RecordDayNo', 'KCAL', 'PROT', 'TFAT', 'CARB', 'MOIS', 'ALC', 'CAFF', 'THEO', 'SUGR', 'FIBE', 'CALC', 'IRON', 'MAGN', 'PHOS', 'POTA', 'SODI', 'ZINC', 'COPP', 'SELE', 'VC', 'VB1', 'VB2', 'NIAC', 'VB6', 'FOLA', 'FA', 'FF', 'FDFE', 'VB12', 'VARA', 'RET', 'BCAR', 'ACAR', 'CRYP', 'LYCO', 'LZ', 'ATOC', 'VK', 'CHOLE', 'SFAT', 'S040', 'S060', 'S080', 'S100', 'S120', 'S140', 'S160', 'S180', 'MFAT', 'M161', 'M181', 'M201', 'M221', 'PFAT', 'P182', 'P183', 'P184', 'P204', 'P205', 'P225', 'P226', 'VITD', 'CHOLN', 'VITE_ADD', 'B12_ADD', 'F_TOTAL', 'F_CITMLB', 'F_OTHER', 'F_JUICE', 'V_TOTAL', 'V_DRKGR', 'V_REDOR_TOTAL', 'V_REDOR_TOMATO', 'V_REDOR_OTHER', 'V_STARCHY_TOTAL', 'V_STARCHY_POTATO', 'V_STARCHY_OTHER', 'V_OTHER', 'V_LEGUMES', 'G_TOTAL', 'G_WHOLE', 'G_REFINED', 'PF_TOTAL', 'PF_MPS_TOTAL', 'PF_MEAT', 'PF_CUREDMEAT', 'PF_ORGAN', 'PF_POULT', 'PF_SEAFD_HI', 'PF_SEAFD_LOW', 'PF_EGGS', 'PF_SOY', 'PF_NUTSDS', 'PF_LEGUMES', 'D_TOTAL', 'D_MILK', 'D_YOGURT', 'D_CHEESE', 'OILS', 'SOLID_FATS', 'ADD_SUGARS', 'A_DRINKS', 'Replicate']

# %%
# Define expected nutrient columns and check which ones are present

nutrient_columns = ["KCAL", "FIBE", "CARB"]

# Try to add fat column automatically if it exists under a common name
fat_candidates = ["FAT", "TFAT", "TotalFat", "Fat", "Total_Fat"]

for col in fat_candidates:
    if col in df_nutrients.columns:
        nutrient_columns.append(col)
        break

existing_nutrient_columns = [col for col in nutrient_columns if col in df_nutrients.columns]

print("Selected nutrient columns:")
print(existing_nutrient_columns)

print("\nMissing expected columns:")
print(set(nutrient_columns) - set(existing_nutrient_columns))
# Out:
# Selected nutrient columns:
# ['KCAL', 'FIBE', 'CARB', 'TFAT']
#
# Missing expected columns:
# set()

# %%
# Analyze missing data in the selected nutrient columns

missing_percentages = (
    df_nutrients[existing_nutrient_columns]
    .isnull()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
)

missing_df = missing_percentages.reset_index()
missing_df.columns = ["Feature", "Missing Percentage"]

display(missing_df)
# Out:
#   Feature  Missing Percentage
# 0    KCAL                 0.0
# 1    FIBE                 0.0
# 2    CARB                 0.0
# 3    TFAT                 0.0

# %%
# Visualize missing data patterns

msno.matrix(df_nutrients[existing_nutrient_columns])
plt.title("Missing Values Matrix - Dietary Records")
plt.show()

msno.bar(df_nutrients[existing_nutrient_columns])
plt.title("Missing Values Bar Plot - Dietary Records")
plt.show()

# %%
# Create a bar plot for missing percentages

plt.figure(figsize=(8, 4))
sns.barplot(data=missing_df, x="Feature", y="Missing Percentage")
plt.title("Missing Values Percentage in Dietary Nutrient Columns")
plt.xlabel("Nutrient")
plt.ylabel("Missing Values (%)")
plt.ylim(0, 100)
plt.xticks(rotation=45)
plt.show()

# %%
# Load participant metadata containing Age and BMI

df_metadata = pd.read_csv(metadata_path, sep="\t")
df_metadata.columns = df_metadata.columns.str.strip()

print("Metadata shape:", df_metadata.shape)
display(df_metadata.head())

print("Metadata columns:")
print(df_metadata.columns.tolist())
# Out:
# Metadata shape: (566, 29)
#     #SampleID UserName  StudyDayNo StudyDate Sample.Week.Day  DietDayNo  \
# 0  MCT.f.0001   MCTs01           1   1/31/17         Tuesday          0
# 1  MCT.f.0002   MCTs01           2    2/1/17       Wednesday          1
# 2  MCT.f.0003   MCTs01           3    2/2/17        Thursday          2
# 3  MCT.f.0004   MCTs01           4    2/3/17          Friday          3
# 4  MCT.f.0005   MCTs01           5    2/4/17        Saturday          4
#
#   Diet.Record.Date Diet.Week.Day Gender   Age  ...  BMI.1  Weight.Change  \
# 0          1/30/17        Monday      F  25.9  ...   25.0           -0.4
# 1          1/31/17       Tuesday      F  25.9  ...   25.0           -0.4
# 2           2/1/17     Wednesday      F  25.9  ...   25.0           -0.4
# 3           2/2/17      Thursday      F  25.9  ...   25.0           -0.4
# 4           2/3/17        Friday      F  25.9  ...   25.0           -0.4
#
#    Run1.Plate Run2.Rerun  SampleOrder SampleType  Timing  Activity.Factor  \
# 0         5.0        NaN         54.0     Sample     Pre            1.375
# 1         1.0        NaN         39.0     Sample     Pre            1.375
# 2         1.0        NaN         59.0     Sample     Pre            1.375
# 3         5.0        NaN         32.0     Sample     Pre            1.375
# 4         2.0        Yes         89.0     Sample     Pre            1.375
#
#               Medications                  Dietary.Supp
# 0  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 1  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 2  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 3  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 4  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
#
# [5 rows x 29 columns]
# Metadata columns:
# ['#SampleID', 'UserName', 'StudyDayNo', 'StudyDate', 'Sample.Week.Day', 'DietDayNo', 'Diet.Record.Date', 'Diet.Week.Day', 'Gender', 'Age', 'Weight', 'Height', 'BMI', 'Supplement', 'Waist.Circumference', 'Study.Status', 'oilGrams.assigned', 'fecal.status', 'fecal.time', 'BMI.1', 'Weight.Change', 'Run1.Plate', 'Run2.Rerun', 'SampleOrder', 'SampleType', 'Timing', 'Activity.Factor', 'Medications', 'Dietary.Supp']

# %%
# Select participant-level metadata columns

profile_columns = ["Age", "BMI"]

df_profile = (
    df_metadata[["UserName"] + profile_columns]
    .drop_duplicates(subset="UserName")
    .copy()
)

print("Profile dataframe shape:", df_profile.shape)
display(df_profile.head())

print("Missing values in profile columns:")
display(df_profile[profile_columns].isnull().mean().mul(100))
# Out:
# Profile dataframe shape: (34, 3)
#    UserName   Age   BMI
# 0    MCTs01  25.9  25.0
# 17   MCTs03  25.4  26.6
# 33   MCTs04  24.0  18.9
# 50   MCTs05  23.1  19.9
# 57   MCTs06  23.7  22.7
# Missing values in profile columns:
# Age    0.0
# BMI    0.0
# dtype: float64

# %%
# Aggregate daily dietary records into average nutrient intake per participant

df_dietary_analysis = (
    df_nutrients
    .groupby("UserName")[existing_nutrient_columns]
    .mean()
    .reset_index()
)

print("Dietary analysis shape:", df_dietary_analysis.shape)
display(df_dietary_analysis.head())
# Out:
# Dietary analysis shape: (37, 5)
#   UserName         KCAL       FIBE        CARB        TFAT
# 0   MCTs01  2233.971687  23.530833  246.315305   72.793184
# 1   MCTs02  1406.094472  12.205770  102.572981   88.889560
# 2   MCTs03  3797.839598  32.528277  379.484855  179.378471
# 3   MCTs04  2554.895951  33.822869  259.635868  123.521241
# 4   MCTs05  1459.168123  13.046344  193.945721   51.869562

# %%
# Merge dietary averages with participant metadata

df_analysis_full = df_dietary_analysis.merge(
    df_profile,
    on="UserName",
    how="left"
)

print("Full analysis dataframe shape:", df_analysis_full.shape)
display(df_analysis_full.head())

print("Missing values after merge:")
display(df_analysis_full[existing_nutrient_columns + profile_columns].isnull().mean().mul(100))
# Out:
# Full analysis dataframe shape: (37, 7)
#   UserName         KCAL       FIBE        CARB        TFAT   Age   BMI
# 0   MCTs01  2233.971687  23.530833  246.315305   72.793184  25.9  25.0
# 1   MCTs02  1406.094472  12.205770  102.572981   88.889560   NaN   NaN
# 2   MCTs03  3797.839598  32.528277  379.484855  179.378471  25.4  26.6
# 3   MCTs04  2554.895951  33.822869  259.635868  123.521241  24.0  18.9
# 4   MCTs05  1459.168123  13.046344  193.945721   51.869562  23.1  19.9
# Missing values after merge:
# KCAL    0.000000
# FIBE    0.000000
# CARB    0.000000
# TFAT    0.000000
# Age     8.108108
# BMI     8.108108
# dtype: float64

# %%
# Missing values summary after merging dietary records with participant metadata

missing_after_merge = (
    df_analysis_full[existing_nutrient_columns + profile_columns]
    .isnull()
    .sum()
    .reset_index()
)

missing_after_merge.columns = ["Feature", "Missing Count"]
missing_after_merge["Missing Percentage"] = (
    missing_after_merge["Missing Count"] / len(df_analysis_full) * 100
)

display(missing_after_merge)
# Out:
#   Feature  Missing Count  Missing Percentage
# 0    KCAL              0            0.000000
# 1    FIBE              0            0.000000
# 2    CARB              0            0.000000
# 3    TFAT              0            0.000000
# 4     Age              3            8.108108
# 5     BMI              3            8.108108

# %%
# Identify participants with dietary records but missing participant metadata

missing_profile_users = df_analysis_full[
    df_analysis_full["Age"].isna() | df_analysis_full["BMI"].isna()
]["UserName"].tolist()

print("Number of participants with missing Age/BMI:", len(missing_profile_users))
print("Participants with missing Age/BMI:")
print(missing_profile_users)
# Out:
# Number of participants with missing Age/BMI: 3
# Participants with missing Age/BMI:
# ['MCTs02', 'MCTs17', 'MCTs30']

# %%
# Compare participants available in dietary records vs. participant metadata

diet_users = set(df_dietary_analysis["UserName"])
profile_users = set(df_profile["UserName"])

users_only_in_diet = sorted(diet_users - profile_users)
users_only_in_profile = sorted(profile_users - diet_users)

print("Number of participants in dietary records:", len(diet_users))
print("Number of participants in metadata:", len(profile_users))

print("\nParticipants found in dietary records but missing from metadata:")
print(users_only_in_diet)

print("\nParticipants found in metadata but missing from dietary records:")
print(users_only_in_profile)
# Out:
# Number of participants in dietary records: 37
# Number of participants in metadata: 34
#
# Participants found in dietary records but missing from metadata:
# ['MCTs02', 'MCTs17', 'MCTs30']
#
# Participants found in metadata but missing from dietary records:
# []

# %%
# Histograms for nutrient intake and participant characteristics

analysis_columns = existing_nutrient_columns + profile_columns

for col in analysis_columns:
    plt.figure(figsize=(7, 4))
    sns.histplot(df_analysis_full[col].dropna(), kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Number of Participants")
    plt.show()

# %%
# Boxplots for nutrient intake and participant characteristics

for col in analysis_columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df_analysis_full[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.ylabel(col)
    plt.show()

# %%
# Create a complete-case dataset for analyses requiring participant metadata

df_analysis_complete = df_analysis_full.dropna(subset=["Age", "BMI"]).copy()

print("Original merged dataset shape:", df_analysis_full.shape)
print("Complete-case dataset shape:", df_analysis_complete.shape)

display(df_analysis_complete.head())
# Out:
# Original merged dataset shape: (37, 7)
# Complete-case dataset shape: (34, 7)
#   UserName         KCAL       FIBE        CARB        TFAT   Age   BMI
# 0   MCTs01  2233.971687  23.530833  246.315305   72.793184  25.9  25.0
# 2   MCTs03  3797.839598  32.528277  379.484855  179.378471  25.4  26.6
# 3   MCTs04  2554.895951  33.822869  259.635868  123.521241  24.0  18.9
# 4   MCTs05  1459.168123  13.046344  193.945721   51.869562  23.1  19.9
# 5   MCTs06  2821.157393  25.010255  300.566053  119.229383  23.7  22.7

# %%
# Descriptive statistics for dietary and participant-level variables

summary_stats = df_analysis_full[analysis_columns].describe().T
display(summary_stats)
# Out:
#       count         mean         std          min          25%          50%  \
# KCAL   37.0  2033.297533  555.341419  1038.411469  1647.969946  1986.314418
# FIBE   37.0    21.501996    8.227874    12.205770    15.555740    19.614496
# CARB   37.0   219.889581   60.207579   102.572981   183.135589   215.304862
# TFAT   37.0    88.114532   30.307293    37.064239    68.770390    88.392512
# Age    34.0    30.823529   10.263264    19.700000    23.750000    28.200000
# BMI    34.0    23.091176    3.315470    17.000000    20.800000    22.800000
#
#               75%          max
# KCAL  2338.837036  3797.839598
# FIBE    24.741995    51.493771
# CARB   253.876709   379.484855
# TFAT   103.046069   179.378471
# Age     36.125000    61.600000
# BMI     25.750000    31.600000

# %%
# Descriptive statistics for dietary and participant-level variables without missing metadata


summary_stats = df_analysis_complete[analysis_columns].describe().T
display(summary_stats)
# Out:
#       count         mean         std          min          25%          50%  \
# KCAL   34.0  2080.282967  554.371204  1038.411469  1720.475921  2053.170958
# FIBE   34.0    21.914465    8.363119    12.578621    16.016949    20.144428
# CARB   34.0   226.308557   57.376045   118.539338   194.193916   224.196062
# TFAT   34.0    89.682832   30.884412    37.064239    69.391504    89.026639
# Age    34.0    30.823529   10.263264    19.700000    23.750000    28.200000
# BMI    34.0    23.091176    3.315470    17.000000    20.800000    22.800000
#
#               75%          max
# KCAL  2381.937003  3797.839598
# FIBE    24.943190    51.493771
# CARB   255.340657   379.484855
# TFAT   105.218414   179.378471
# Age     36.125000    61.600000
# BMI     25.750000    31.600000

# %% [markdown]
# EDA on CFMD

# %% [markdown]
# # CFMD Food Microbiome Analysis
#
# **Data source:** CuratedFoodMetagenomicData (CFMD)
# - `cFMD-main/cFMD-main/cFMD_metadata.tsv` — sample metadata with `category`, `sample_id`
# - `cFMD-main/cFMD-main/cFMD_data/**/*_taxonomic_profiles.tsv` — per-dataset abundance matrices
#
# **Tasks:**
# 1. Explore CFMD and analyze food microbial richness per category
# 2. Check species overlap between the top-2 richest categories

# %% [markdown]
# ## Cell 1 — Setup and Metadata Loading

# %%
import os
import glob
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid')
plt.rcParams['figure.dpi'] = 120

# ── Load metadata ─────────────────────────────────────────────────────────────
#metadata = pd.read_csv('./cFMD-main/cFMD-main/cFMD_metadata.tsv', sep='\t')
metadata = pd.read_csv('./data/cFMD-main/cFMD-main/cFMD_metadata.tsv', sep='\t')
metadata.columns = metadata.columns.astype(str).str.strip()
metadata['sample_id'] = metadata['sample_id'].astype(str).str.strip()

print('=== CFMD Metadata ===')
print(f'Shape   : {metadata.shape}')
print(f'Columns : {metadata.columns.tolist()}')
print()

# ── EDA: category distribution ────────────────────────────────────────────────
cat_counts = metadata['category'].value_counts()
print(f"'category' — {cat_counts.shape[0]} unique values:")
print(cat_counts.to_string())

fig, ax = plt.subplots(figsize=(13, 4))
cat_counts.head(15).plot(kind='bar', ax=ax, color='steelblue', edgecolor='white')
ax.set_title('CFMD: Sample Count per Food Category (top 15)', fontsize=13)
ax.set_xlabel('Category')
ax.set_ylabel('Sample Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('category_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved → category_distribution.png')

# ── EDA: macrocategory distribution ──────────────────────────────────────────
print()
print('Macrocategory counts:')
print(metadata['macrocategory'].value_counts().to_string())

# ── EDA: sequencing platform ──────────────────────────────────────────────────
print()
print('Sequencing platform counts:')
print(metadata['sequencing_platform'].value_counts().to_string())
# Out:
# === CFMD Metadata ===
# Shape   : (3444, 32)
# Columns : ['dataset_name', 'sample_id', 'macrocategory', 'category', 'type', 'subtype', 'commercial_name', 'fermented/non-fermented', 'country', 'sample_accession', 'run_accession', 'experiment_accession', 'study_accession', 'project_accession', 'database_origin', 'library_layout', 'sequencing_platform', 'DNA_extraction_kit', 'collection_date', 'n_of_bases', 'n_of_reads', 'min_read_len', 'median_read_len', 'mean_read_len', 'max_read_len', 'n_contigs', 'n_MAGs_MQ_prok', 'n_MAGs_HQ_prok', 'n_MAGs_MQ_euk', 'n_MAGs_HQ_euk', 'filtered', 'curator']
#
# 'category' — 15 unique values:
# category
# dairy                              2296
# fermented_beverages                 435
# fermented_meat                      157
# meat                                119
# fish                                 93
# fermented_grains                     83
# fermented_seeds                      65
# fermented_fruits_and_vegetables      52
# alcohol                              48
# fruits_and_vegetables                25
# fermented_tubers_and_roots           24
# fermented_legumes                    20
# probiotics                           14
# other                                 8
# fermented_fish                        5
# Plot saved → category_distribution.png
#
# Macrocategory counts:
# macrocategory
# food    3444
#
# Sequencing platform counts:
# sequencing_platform
# Illumina_NovaSeq_6000          1616
# NextSeq_500                    1053
# Illumina_MiSeq                  283
# HiSeq X Ten                     119
# Illumina_HiSeq_2500             102
# Illumina_HiSeq_4000              75
# NextSeq_550                      71
# Illumina_HiSeq_2000              41
# HiSeq_X_Ten                      20
# Illumina_HiSeq_1500              15
# Illumina_HiSeq_XTen              14
# Illumina HiSeq 4000              13
# Ion_Torrent_PGM                  10
# Illumina NovaSeq 6000             4
# Illumina MiSeq                    2
# Illumina_Genome_Analyzer_II       2
# Illumina_HiSeq_1000               2
# Sequel;Illumina_MiSeq             1
# Illumina HiSeq X                  1

# %% [markdown]
# ## Cell 2 — Load Taxonomic Profiles and Merge with Metadata
#
# Each `*_taxonomic_profiles.tsv` file is a wide matrix: rows = taxa, columns = samples.
# Column names are formatted as `DatasetName__SampleAccession`.
# We extract the accession part (after `__`) to match `sample_id` in the metadata.

# %%
# profile_files = glob.glob(
#     './cFMD-main/cFMD-main/cFMD_data/**/*_taxonomic_profiles.tsv',
#     recursive=True
# )
profile_files = glob.glob(
    './data/cFMD-main/cFMD-main/cFMD_data/**/*_taxonomic_profiles.tsv',
    recursive=True
)
print(f'Found {len(profile_files)} taxonomic profile files')

all_profiles = []
skipped = []

for path in profile_files:
    try:
        df = pd.read_csv(path, sep='\t')
        # First column is always the taxonomy column
        tax_col = df.columns[0]
        df = df.rename(columns={tax_col: '#taxonomy'})

        # Melt wide → long
        long = df.melt(
            id_vars=['#taxonomy'],
            var_name='sample_col',
            value_name='abundance'
        )

        # Column names: 'DatasetName__SampleAccession' → extract accession after '__'
        long['sample_id'] = long['sample_col'].str.split('__').str[-1]
        long = long.drop(columns=['sample_col'])
        all_profiles.append(long)

    except Exception as e:
        skipped.append((path, str(e)))

if skipped:
    print(f'\nSkipped {len(skipped)} files:')
    for p, e in skipped:
        print(f'  {p}: {e}')

# Combine all datasets
long_df = pd.concat(all_profiles, ignore_index=True)
long_df['sample_id'] = long_df['sample_id'].astype(str).str.strip()
long_df['abundance'] = pd.to_numeric(long_df['abundance'], errors='coerce').fillna(0)

print(f'\nCombined long-format shape : {long_df.shape}')
print(f'Unique sample IDs in profiles : {long_df["sample_id"].nunique()}')
print(f'Unique taxa in profiles       : {long_df["#taxonomy"].nunique()}')


# ── Merge with metadata ───────────────────────────────────────────────────────
merged = long_df.merge(
    metadata[['sample_id', 'category', 'macrocategory', 'country', 'fermented/non-fermented']],
    on='sample_id',
    how='left'
)

# Filter: keep only rows with positive abundance
merged_filtered = merged[merged['abundance'] > 0].copy()

print(f'\nRows after filtering (abundance > 0) : {len(merged_filtered):,}')
print(f'Unique taxa retained                 : {merged_filtered["#taxonomy"].nunique()}')
print(f'Missing category (unmatched samples) : {merged_filtered["category"].isna().sum():,}')
print(f'Categories present                   : {merged_filtered["category"].nunique()}')
print()
print('Sample category distribution:')
print(merged_filtered.dropna(subset=['category'])["category"].value_counts().to_string())

display(merged_filtered.head())
# Out:
# Found 85 taxonomic profile files
#
# Combined long-format shape : (1614609, 3)
# Unique sample IDs in profiles : 3392
# Unique taxa in profiles       : 5057
#
# Rows after filtering (abundance > 0) : 94,491
# Unique taxa retained                 : 5051
# Missing category (unmatched samples) : 0
# Categories present                   : 15
#
# Sample category distribution:
# category
# dairy                              57653
# fermented_beverages                 7663
# fermented_meat                      5649
# meat                                4976
# fish                                4558
# fermented_seeds                     4537
# fruits_and_vegetables               2883
# fermented_fruits_and_vegetables     1637
# fermented_tubers_and_roots          1465
# fermented_grains                    1161
# alcohol                              944
# fermented_legumes                    936
# other                                223
# probiotics                           114
# fermented_fish                        92
#                                             #taxonomy  abundance   sample_id  \
# 0   k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactob...    0.14109  SRR8742576
# 3   k__Bacteria|p__Pseudomonadota|c__Gammaproteoba...    0.10390  SRR8742576
# 7   k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactob...   14.74891  SRR8742576
# 12  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactob...    0.33599  SRR8742576
# 20  k__Eukaryota|p__Ascomycota|c__Saccharomycetes|...    0.89747  SRR8742576
#
#            category macrocategory country fermented/non-fermented
# 0   fermented_seeds          food     BRA                       F
# 3   fermented_seeds          food     BRA                       F
# 7   fermented_seeds          food     BRA                       F
# 12  fermented_seeds          food     BRA                       F
# 20  fermented_seeds          food     BRA                       F

# %% [markdown]
# ## Cell 3 — Task 1: Microbial Richness per Food Category
#
# **Richness** = number of unique taxa with abundance > 0 per food category.

# %%
# Guard: verify merge succeeded
if 'category' not in merged_filtered.columns or merged_filtered['category'].isna().all():
    raise RuntimeError('category data is missing — merge did not succeed. Fix Cell 2.')

richness = (
    merged_filtered
    .dropna(subset=['category'])
    .groupby('category')['#taxonomy']
    .nunique()
    .reset_index(name='microbial_richness')
    .sort_values('microbial_richness', ascending=False)
    .reset_index(drop=True)
)

print('=== Microbial Richness per Food Category ===')
print(richness.to_string(index=False))

# ── Bar chart: top 10 ─────────────────────────────────────────────────────────
top10   = richness.head(10)
palette = sns.color_palette('viridis', len(top10))

fig, ax = plt.subplots(figsize=(13, 5))
bars = ax.bar(
    top10['category'],
    top10['microbial_richness'],
    color=palette,
    edgecolor='white'
)
for bar, val in zip(bars, top10['microbial_richness']):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        str(int(val)),
        ha='center', va='bottom', fontsize=10, fontweight='bold'
    )

ax.set_title('Top 10 Food Categories by Microbial Richness', fontsize=14)
ax.set_xlabel('Food Category', fontsize=12)
ax.set_ylabel('Microbial Richness (Unique Taxa)', fontsize=12)
ax.set_ylim(0, top10['microbial_richness'].max() * 1.15)
plt.xticks(rotation=40, ha='right', fontsize=10)
plt.tight_layout()
plt.savefig('richness_by_category.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved → richness_by_category.png')
# Out:
# === Microbial Richness per Food Category ===
#                        category  microbial_richness
#                           dairy                2967
#                  fermented_meat                 854
#           fruits_and_vegetables                 823
#             fermented_beverages                 751
#                 fermented_seeds                 718
#      fermented_tubers_and_roots                 699
# fermented_fruits_and_vegetables                 529
#                            fish                 490
#                            meat                 380
#               fermented_legumes                 368
#                fermented_grains                 361
#                         alcohol                 330
#                           other                 158
#                  fermented_fish                  44
#                      probiotics                  36
# Plot saved → richness_by_category.png

# %% [markdown]
# ## Cell 4 — Task 2: Species Overlap between Top-2 Categories (Venn Diagram)
#
# We compare the two richest food categories using a Venn diagram and the Jaccard similarity index.

# %%
try:
    from matplotlib_venn import venn2
except ImportError:
    import subprocess, sys
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'matplotlib-venn', '-q'])
    from matplotlib_venn import venn2

cat1, cat2 = richness.head(2)['category'].tolist()
print(f"Comparing: '{cat1}'  vs  '{cat2}'")

sp1    = set(merged_filtered.loc[merged_filtered['category'] == cat1, '#taxonomy'].unique())
sp2    = set(merged_filtered.loc[merged_filtered['category'] == cat2, '#taxonomy'].unique())
shared = sp1 & sp2
union  = sp1 | sp2

print(f"\nSpecies unique to '{cat1}'  : {len(sp1 - sp2):,}")
print(f"Species unique to '{cat2}'  : {len(sp2 - sp1):,}")
print(f"Shared species              : {len(shared):,}")
print(f"Jaccard similarity index    : {len(shared) / len(union):.4f}")

if shared:
    print(f'\nTop shared species (last taxonomic level):')
    for s in sorted(shared)[:20]:  # show first 20
        sep   = '|' if '|' in s else ';'
        label = s.split(sep)[-1].strip()
        print(f'  {label}')
    if len(shared) > 20:
        print(f'  ... and {len(shared) - 20} more')

# ── Venn diagram ──────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(8, 6))
v = venn2(
    subsets=[sp1, sp2],
    set_labels=(cat1, cat2),
    ax=ax,
    set_colors=('#4C72B0', '#DD8452'),
    alpha=0.65
)
for region_id in ('10', '01', '11'):
    lbl = v.get_label_by_id(region_id)
    if lbl:
        lbl.set_fontsize(14)
for set_lbl in v.set_labels:
    if set_lbl:
        set_lbl.set_fontsize(11)
        set_lbl.set_fontweight('bold')

ax.set_title(
    f'Microbial Species Overlap\n"{cat1}"  vs  "{cat2}"\nJaccard = {len(shared)/len(union):.4f}',
    fontsize=12
)
plt.tight_layout()
plt.savefig('venn_species_overlap.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved → venn_species_overlap.png')
# Out:
# Comparing: 'dairy'  vs  'fermented_meat'
#
# Species unique to 'dairy'  : 2,346
# Species unique to 'fermented_meat'  : 233
# Shared species              : 621
# Jaccard similarity index    : 0.1941
#
# Top shared species (last taxonomic level):
#   t__SGB257
#   t__SGB203
#   t__SGB282
#   t__SGB39400
#   t__SGB33761
#   t__SGB23979
#   t__SGB98684
#   t__SGB86828
#   t__SGB17183
#   t__SGB17232
#   t__SGB93302
#   t__SGB98927
#   t__SGB99001
#   t__SGB99002
#   t__SGB16645
#   t__SGB98807
#   t__SGB16638
#   t__SGB98794
#   t__SGB16639
#   t__SGB88049
#   ... and 601 more
# Plot saved → venn_species_overlap.png

# %% [markdown]
# # Loading and Exploring the Paper 1 Microbiome Dataset

# %%
import pandas as pd
import os

#base = r"C:\Users\rtajz\Downloads\dietstudy_analyses-master\dietstudy_analyses-master\data"
base = str(Path.cwd()) + "\data\dietstudy_analyses-master\data"

print(base)
print("Base exists:", os.path.exists(base))

microbiome = pd.read_csv(
    f"{base}/microbiome/processed_sample/taxonomy_counts_s.txt",
    sep="\t",
    index_col=0
)

sample_meta = pd.read_csv(
    f"{base}/maps/food_map.txt",
    sep="\t"
).rename(columns={"#SampleID": "SampleID"})

diet_raw = pd.read_csv(
    f"{base}/diet/processed_food/dhydrt.txt",
    sep="\t",
    index_col=0
)

diet_decay = pd.read_csv(
    f"{base}/diet/processed_food/masterdecaydiet.txt",
    sep="\t",
    index_col=0
)

nutrition_totals = pd.read_csv(
    f"{base}/diet/nutrition_totals.txt",
    sep="\t",
    index_col=0
)

microbiome_clr = pd.read_csv(
    f"{base}/microbiome/processed_sample/taxonomy_clr_s.txt",
    sep="\t",
    index_col=0
)

diet_fiber = pd.read_csv(
    f"{base}/diet/diet.fiber.txt",
    sep="\t",
    index_col=0
)

fiber_avg = pd.read_csv(
    f"{base}/diet/fiber/fiber.smry.otu.txt",
    sep="\t",
    index_col=0
)

micro_avg_counts = pd.read_csv(
    f"{base}/microbiome/processed_average/UN_taxonomy_counts_s.txt",
    sep="\t",
    index_col=0
)

micro_avg_clr = pd.read_csv(
    f"{base}/microbiome/processed_average/UN_taxonomy_clr_s.txt",
    sep="\t",
    index_col=0
)

micro_avg_norm = pd.read_csv(
    f"{base}/microbiome/processed_average/UN_taxonomy_norm_s.txt",
    sep="\t",
    index_col=0
)

print("=== microbiome ===")
print(microbiome.shape)
print(microbiome.head())

print("=== sample_meta ===")
print(sample_meta.shape)
print(sample_meta.head())

print("=== diet_raw ===")
print(diet_raw.shape)
print(diet_raw.head())

print("=== diet_decay ===")
print(diet_decay.shape)
print(diet_decay.head())

print("=== nutrition_totals ===")
print(nutrition_totals.shape)
print(nutrition_totals.head())

print("=== microbiome_clr ===")
print(microbiome_clr.shape)
print(microbiome_clr.head())

print("=== diet_fiber ===")
print(diet_fiber.shape)
print(diet_fiber.head())

print("=== fiber_avg ===")
print(fiber_avg.shape)
print(fiber_avg.head())

print("=== micro_avg_counts ===")
print(micro_avg_counts.shape)
print(micro_avg_counts.head())

print("=== micro_avg_clr ===")
print(micro_avg_clr.shape)
print(micro_avg_clr.head())

print("=== micro_avg_norm ===")
print(micro_avg_norm.shape)
print(micro_avg_norm.head())

microbiome.to_csv("microbiome.csv")
sample_meta.to_csv("sample_meta.csv", index=False)
diet_raw.to_csv("diet_raw.csv")
diet_decay.to_csv("diet_decay.csv")
nutrition_totals.to_csv("nutrition_totals.csv")
microbiome_clr.to_csv("microbiome_clr.csv")
diet_fiber.to_csv("diet_fiber.csv")
fiber_avg.to_csv("fiber_avg.csv")
micro_avg_counts.to_csv("micro_avg_counts.csv")
micro_avg_clr.to_csv("micro_avg_clr.csv")
micro_avg_norm.to_csv("micro_avg_norm.csv")

print("Done! CSV files were saved.")
# Out:
# c:\Users\mayag\PythonForuni\ProjectYear3\data\dietstudy_analyses-master\data
# Base exists: True
# === microbiome ===
# (223, 483)
#                                                     MCT.f.0002  MCT.f.0003  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       79055       33364
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        2421       16944
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       39779        9983
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           1           5
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       18393         561
#
#                                                     MCT.f.0004  MCT.f.0005  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       64027       70720
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       43511       18335
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       31539       44880
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           4           4
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       11742       15831
#
#                                                     MCT.f.0006  MCT.f.0007  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       63361       58636
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       36493       43987
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       29901       31975
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           7           2
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       14319       16541
#
#                                                     MCT.f.0008  MCT.f.0009  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       73520       69225
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       15944       20583
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       41607       39981
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...          13           3
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...        8328       10082
#
#                                                     MCT.f.0010  MCT.f.0011  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       58080       75592
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        5493       23064
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       32774       41183
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           9           4
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       40723       16670
#
#                                                     ...  MCT.f.0618  \
# #taxonomy                                           ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...      116037
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  ...          11
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...       25278
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...           7
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...          11
#
#                                                     MCT.f.0619  MCT.f.0620  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       93723      105413
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...          62           3
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       26608       24590
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...          10           1
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...          52           6
#
#                                                     MCT.f.0621  MCT.f.0622  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      100387       97278
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...           5          23
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       26421       24128
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           0         184
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           9          13
#
#                                                     MCT.f.0623  MCT.f.0624  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      117400      123705
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...           2           7
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       23532       20010
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           2           2
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           5          10
#
#                                                     MCT.f.0625  MCT.f.0627  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       96470      117867
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...          18        2206
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       22195        9340
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           6         142
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           9        1246
#
#                                                     MCT.f.0628
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       93290
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...           5
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       21397
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           1
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           4
#
# [5 rows x 483 columns]
# === sample_meta ===
# (566, 29)
#      SampleID UserName  StudyDayNo StudyDate Sample.Week.Day  DietDayNo  \
# 0  MCT.f.0001   MCTs01           1   1/31/17         Tuesday          0
# 1  MCT.f.0002   MCTs01           2    2/1/17       Wednesday          1
# 2  MCT.f.0003   MCTs01           3    2/2/17        Thursday          2
# 3  MCT.f.0004   MCTs01           4    2/3/17          Friday          3
# 4  MCT.f.0005   MCTs01           5    2/4/17        Saturday          4
#
#   Diet.Record.Date Diet.Week.Day Gender   Age  ...  BMI.1  Weight.Change  \
# 0          1/30/17        Monday      F  25.9  ...   25.0           -0.4
# 1          1/31/17       Tuesday      F  25.9  ...   25.0           -0.4
# 2           2/1/17     Wednesday      F  25.9  ...   25.0           -0.4
# 3           2/2/17      Thursday      F  25.9  ...   25.0           -0.4
# 4           2/3/17        Friday      F  25.9  ...   25.0           -0.4
#
#    Run1.Plate Run2.Rerun  SampleOrder SampleType  Timing  Activity.Factor  \
# 0         5.0        NaN         54.0     Sample     Pre            1.375
# 1         1.0        NaN         39.0     Sample     Pre            1.375
# 2         1.0        NaN         59.0     Sample     Pre            1.375
# 3         5.0        NaN         32.0     Sample     Pre            1.375
# 4         2.0        Yes         89.0     Sample     Pre            1.375
#
#               Medications                  Dietary.Supp
# 0  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 1  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 2  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 3  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
# 4  Nexplanon (bc implant)   Multivitamin;VitD;VitC;Zinc
#
# [5 rows x 29 columns]
# === diet_raw ===
# (1452, 567)
#                                                     MCT.f.0065  MCT.f.0070  \
# #FoodID
# Milk NFS                                                6.5575      104.92
# Milk cows fluid whole                                   0.0000        0.00
# Milk cows fluid 2 fat                                   0.0000        0.00
# Milk cows fluid 1 fat                                   0.0000        0.00
# Milk cows fluid skim or nonfat 0 5 or less butt...      0.0000        0.00
#
#                                                     MCT.f.0071  MCT.f.0072  \
# #FoodID
# Milk NFS                                               11.8035      6.5575
# Milk cows fluid whole                                   0.0000      0.0000
# Milk cows fluid 2 fat                                   0.0000      0.0000
# Milk cows fluid 1 fat                                   0.0000      0.0000
# Milk cows fluid skim or nonfat 0 5 or less butt...      0.0000      0.0000
#
#                                                     MCT.f.0073  MCT.f.0074  \
# #FoodID
# Milk NFS                                                6.5575       26.23
# Milk cows fluid whole                                   0.0000        0.00
# Milk cows fluid 2 fat                                   0.0000        0.00
# Milk cows fluid 1 fat                                   0.0000        0.00
# Milk cows fluid skim or nonfat 0 5 or less butt...      0.0000        0.00
#
#                                                     MCT.f.0095  MCT.f.0099  \
# #FoodID
# Milk NFS                                             41.968000       52.46
# Milk cows fluid whole                                59.735775        0.00
# Milk cows fluid 2 fat                                 0.000000        0.00
# Milk cows fluid 1 fat                                 0.000000        0.00
# Milk cows fluid skim or nonfat 0 5 or less butt...    0.000000        0.00
#
#                                                     MCT.f.0100  MCT.f.0260  \
# #FoodID
# Milk NFS                                                39.345     19.6725
# Milk cows fluid whole                                    0.000      0.0000
# Milk cows fluid 2 fat                                    0.000      0.0000
# Milk cows fluid 1 fat                                    0.000      0.0000
# Milk cows fluid skim or nonfat 0 5 or less butt...       0.000      0.0000
#
#                                                     ...  MCT.f.0204  \
# #FoodID                                             ...
# Milk NFS                                            ...         0.0
# Milk cows fluid whole                               ...         0.0
# Milk cows fluid 2 fat                               ...         0.0
# Milk cows fluid 1 fat                               ...         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...  ...         0.0
#
#                                                     MCT.f.0175  MCT.f.0176  \
# #FoodID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0183  MCT.f.0184  \
# #FoodID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0193  MCT.f.0194  \
# #FoodID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0199  MCT.f.0200  \
# #FoodID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                                                              taxonomy
# #FoodID
# Milk NFS                                            L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid whole                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid 2 fat                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid 1 fat                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid skim or nonfat 0 5 or less butt...  L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
#
# [5 rows x 567 columns]
# === diet_decay ===
# (1452, 564)
#                                                     MCT.f.0001  MCT.f.0002  \
# #SampleID
# Milk NFS                                               0.00000     0.00000
# Milk cows fluid whole                                  0.00000     0.00000
# Milk cows fluid 2 fat                                  0.00000     0.00000
# Milk cows fluid 1 fat                                  0.00000     0.00000
# Milk cows fluid skim or nonfat 0 5 or less butt...    44.84736    67.27104
#
#                                                     MCT.f.0003  MCT.f.0004  \
# #SampleID
# Milk NFS                                                0.0000     0.00000
# Milk cows fluid whole                                   0.0000     0.00000
# Milk cows fluid 2 fat                                   0.0000     0.00000
# Milk cows fluid 1 fat                                   0.0000     0.00000
# Milk cows fluid skim or nonfat 0 5 or less butt...     56.0592    72.87696
#
#                                                     MCT.f.0005  MCT.f.0006  \
# #SampleID
# Milk NFS                                               0.00000     0.00000
# Milk cows fluid whole                                  0.00000     0.00000
# Milk cows fluid 2 fat                                  0.00000     0.00000
# Milk cows fluid 1 fat                                  0.00000     0.00000
# Milk cows fluid skim or nonfat 0 5 or less butt...    81.28584    40.64292
#
#                                                     MCT.f.0007  MCT.f.0008  \
# #SampleID
# Milk NFS                                               0.00000     0.00000
# Milk cows fluid whole                                  0.00000     0.00000
# Milk cows fluid 2 fat                                  0.00000     0.00000
# Milk cows fluid 1 fat                                  0.00000     0.00000
# Milk cows fluid skim or nonfat 0 5 or less butt...    65.16882    77.43177
#
#                                                     MCT.f.0009  MCT.f.0010  \
# #SampleID
# Milk NFS                                              0.000000    0.000000
# Milk cows fluid whole                                 0.000000    0.000000
# Milk cows fluid 2 fat                                 0.000000    0.000000
# Milk cows fluid 1 fat                                 0.000000    0.000000
# Milk cows fluid skim or nonfat 0 5 or less butt...   83.563245   86.628983
#
#                                                     ...  MCT.f.0621  \
# #SampleID                                           ...
# Milk NFS                                            ...    6.557500
# Milk cows fluid whole                               ...    0.000000
# Milk cows fluid 2 fat                               ...    0.617053
# Milk cows fluid 1 fat                               ...    0.000000
# Milk cows fluid skim or nonfat 0 5 or less butt...  ...    0.043832
#
#                                                     MCT.f.0622  MCT.f.0623  \
# #SampleID
# Milk NFS                                              4.590250    2.295125
# Milk cows fluid whole                                 0.000000    0.000000
# Milk cows fluid 2 fat                                 0.308527    0.154263
# Milk cows fluid 1 fat                                 0.000000    0.000000
# Milk cows fluid skim or nonfat 0 5 or less butt...    0.021916    0.010958
#
#                                                     MCT.f.0624  MCT.f.0625  \
# #SampleID
# Milk NFS                                              7.705063    7.131281
# Milk cows fluid whole                                 0.000000    0.000000
# Milk cows fluid 2 fat                                 0.077132    0.038566
# Milk cows fluid 1 fat                                 0.000000    0.000000
# Milk cows fluid skim or nonfat 0 5 or less butt...    0.005479    0.002740
#
#                                                     MCT.f.0626  MCT.f.0627  \
# #SampleID
# Milk NFS                                              3.565641    1.782820
# Milk cows fluid whole                                 0.000000    0.000000
# Milk cows fluid 2 fat                                 0.019283    0.009641
# Milk cows fluid 1 fat                                 0.000000    0.000000
# Milk cows fluid skim or nonfat 0 5 or less butt...    0.001370    0.000685
#
#                                                     MCT.f.0628  MCT.f.0629  \
# #SampleID
# Milk NFS                                              0.891410    0.445705
# Milk cows fluid whole                                 0.000000    0.000000
# Milk cows fluid 2 fat                                 0.004821    0.002410
# Milk cows fluid 1 fat                                 0.000000    0.000000
# Milk cows fluid skim or nonfat 0 5 or less butt...    0.000342    0.000171
#
#                                                                                              taxonomy
# #SampleID
# Milk NFS                                            L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid whole                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid 2 fat                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid 1 fat                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid skim or nonfat 0 5 or less butt...  L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
#
# [5 rows x 564 columns]
# === nutrition_totals ===
# (580, 106)
#            UserName StudyDayNo  RecordDayNo         KCAL        PROT  \
# X.SampleID
# MCT.f.0001   MCTs01     Day.01            1  1707.040193   95.668747
# MCT.f.0002   MCTs01     Day.02            2  1970.043625  109.619765
# MCT.f.0003   MCTs01     Day.03            3  1714.895330   89.992993
# MCT.f.0004   MCTs01     Day.04            4  2487.232625   94.611953
# MCT.f.0005   MCTs01     Day.05            5  2260.211176  110.268353
#
#                  TFAT        CARB         MOIS       ALC     CAFF  ...  \
# X.SampleID                                                         ...
# MCT.f.0001  55.185318  187.965353  3848.605502  14.95872  331.520  ...
# MCT.f.0002  53.615264  242.919015  3808.005721  14.04000  378.880  ...
# MCT.f.0003  50.561373  234.225138  4183.622433   0.00000  378.880  ...
# MCT.f.0004  92.021551  257.539030  4816.211548  42.44800  379.430  ...
# MCT.f.0005  95.570253  165.608070  4404.243876  43.93060  534.545  ...
#
#             PF_LEGUMES   D_TOTAL   D_MILK  D_YOGURT  D_CHEESE       OILS  \
# X.SampleID
# MCT.f.0001         0.0  3.265577  2.05776     0.646  0.561817  14.668870
# MCT.f.0002         0.0  4.156035  2.35656     0.646  1.153475  15.886225
# MCT.f.0003         0.0  2.979655  1.12608     0.646  1.207575  11.836920
# MCT.f.0004         0.0  3.634460  2.15186     0.000  1.482600  55.308100
# MCT.f.0005         0.0  3.379710  2.32071     0.000  1.059000  24.231213
#
#             SOLID_FATS  ADD_SUGARS  A_DRINKS  Replicate
# X.SampleID
# MCT.f.0001   21.795872    4.822350  1.072512          1
# MCT.f.0002   19.139825    4.325970  1.008000          1
# MCT.f.0003   17.711575    4.758330  0.000000          1
# MCT.f.0004   19.937800    5.917100  3.035200          1
# MCT.f.0005   54.613613    5.793898  3.116360          1
#
# [5 rows x 106 columns]
# === microbiome_clr ===
# (223, 483)
#                                                     MCT.f.0002  MCT.f.0003  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         1.186262    1.625297
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.080382    3.022691
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    3.469741    5.591312
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -3.774249   -1.793918
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -0.812418    1.060460
#
#                                                     MCT.f.0004  MCT.f.0005  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         0.741324    0.392266
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.255423    0.347146
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    3.953290    2.941252
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -3.657232   -3.371488
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -0.994644   -1.119191
#
#                                                     MCT.f.0006  MCT.f.0007  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         0.976799    1.062720
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    0.561672    1.215690
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    2.975329    3.762472
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -3.761890   -3.039923
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -1.128618   -0.992230
#
#                                                     MCT.f.0008  MCT.f.0009  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         1.083087    0.998056
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    0.894150    1.189256
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    3.326831    3.763091
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -3.140091   -2.910628
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -1.435343   -0.873746
#
#                                                     MCT.f.0010  MCT.f.0011  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         0.703716    0.919841
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    2.323907    1.114987
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    5.036699    3.688212
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -2.214055   -3.675279
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -0.134613   -0.822648
#
#                                                     ...  MCT.f.0618  \
# #taxonomy                                           ...
# k__Bacteria;NA;NA;NA;NA;NA;NA                       ...    1.302527
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  ...    2.663503
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  ...    0.386236
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  ...   -2.636809
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  ...    1.288138
#
#                                                     MCT.f.0619  MCT.f.0620  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         0.801082    2.234895
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.899695    2.862261
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -1.084234    0.619227
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -1.111144   -3.314255
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.088764    1.733343
#
#                                                     MCT.f.0621  MCT.f.0622  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         1.111533    1.233751
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    3.453940    3.359002
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.046995    1.539133
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -1.992744   -1.405306
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    2.299758    2.326393
#
#                                                     MCT.f.0623  MCT.f.0624  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         2.419189    1.116031
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    3.325620    2.712730
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.293806    0.460156
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -2.061929   -2.926201
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    2.096954    1.447064
#
#                                                     MCT.f.0625  MCT.f.0627  \
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         0.703760    1.494869
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    2.556144    3.852903
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    0.821543    1.660723
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -2.276697   -1.721783
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.745214    2.668543
#
#                                                     MCT.f.0628
# #taxonomy
# k__Bacteria;NA;NA;NA;NA;NA;NA                         0.991135
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    2.764202
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    0.543110
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...   -2.144952
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...    1.670296
#
# [5 rows x 483 columns]
# === diet_fiber ===
# (1452, 581)
#                                                     MCT.f.0065  MCT.f.0070  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0071  MCT.f.0072  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0073  MCT.f.0074  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0076  MCT.f.0085  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0095  MCT.f.0099  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     ...  MCT.f.0204  \
# #FOODID                                             ...
# Milk NFS                                            ...           0
# Milk cows fluid whole                               ...           0
# Milk cows fluid 2 fat                               ...           0
# Milk cows fluid 1 fat                               ...           0
# Milk cows fluid skim or nonfat 0 5 or less butt...  ...           0
#
#                                                     MCT.f.0175  MCT.f.0176  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0183  MCT.f.0184  \
# #FOODID
# Milk NFS                                                   0.0         0.0
# Milk cows fluid whole                                      0.0         0.0
# Milk cows fluid 2 fat                                      0.0         0.0
# Milk cows fluid 1 fat                                      0.0         0.0
# Milk cows fluid skim or nonfat 0 5 or less butt...         0.0         0.0
#
#                                                     MCT.f.0193  MCT.f.0194  \
# #FOODID
# Milk NFS                                                     0           0
# Milk cows fluid whole                                        0           0
# Milk cows fluid 2 fat                                        0           0
# Milk cows fluid 1 fat                                        0           0
# Milk cows fluid skim or nonfat 0 5 or less butt...           0           0
#
#                                                     MCT.f.0199  MCT.f.0200  \
# #FOODID
# Milk NFS                                                     0           0
# Milk cows fluid whole                                        0           0
# Milk cows fluid 2 fat                                        0           0
# Milk cows fluid 1 fat                                        0           0
# Milk cows fluid skim or nonfat 0 5 or less butt...           0           0
#
#                                                                                              taxonomy
# #FOODID
# Milk NFS                                            L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid whole                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid 2 fat                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid 1 fat                               L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
# Milk cows fluid skim or nonfat 0 5 or less butt...  L1_Milk_and_Milk_Products;L2_Milks_and_milk_dr...
#
# [5 rows x 581 columns]
# === fiber_avg ===
# (1452, 35)
#                                  MCTs01  MCTs03    MCTs04  MCTs05    MCTs06  \
# #FoodID
# Chili with beans without meat  0.000000     0.0  0.000000     0.0  0.000000
# Falafel                        0.130000     0.0  0.000000     0.0  0.000000
# Hummus                         0.361765     0.0  0.615000     0.0  0.000000
# Pork and beans                 0.000000     0.0  0.000000     0.0  0.479956
# Refried beans                  0.340434     0.0  0.310093     0.0  0.000000
#
#                                  MCTs07    MCTs08  MCTs09  MCTs10  MCTs11  \
# #FoodID
# Chili with beans without meat  2.241422  0.000000     0.0     0.0     0.0
# Falafel                        0.000000  0.000000     0.0     0.0     0.0
# Hummus                         0.000000  0.144706     0.0     0.0     0.0
# Pork and beans                 0.000000  0.000000     0.0     0.0     0.0
# Refried beans                  0.000000  0.000000     0.0     0.0     0.0
#
#                                ...  MCTs28  MCTs29    MCTs31    MCTs32  \
# #FoodID                        ...
# Chili with beans without meat  ...     0.0     0.0  0.803647  0.000000
# Falafel                        ...     0.0     0.0  0.000000  0.000000
# Hummus                         ...     0.0     0.0  0.108529  0.000000
# Pork and beans                 ...     0.0     0.0  0.000000  0.000000
# Refried beans                  ...     0.0     0.0  0.000000  0.907824
#
#                                  MCTs33  MCTs34  MCTs35   MCTs36  MCTs37  \
# #FoodID
# Chili with beans without meat  0.000000     0.0     0.0  0.00000     0.0
# Falafel                        0.000000     0.0     0.0  0.00000     0.0
# Hummus                         0.434118     0.0     0.0  0.15375     0.0
# Pork and beans                 0.000000     0.0     0.0  0.00000     0.0
# Refried beans                  0.000000     0.0     0.0  0.00000     0.0
#
#                                                                         taxonomy
# #FoodID
# Chili with beans without meat  L1_Dry_Beans_Peas_Other_Legumes_Nuts_and_Seeds...
# Falafel                        L1_Dry_Beans_Peas_Other_Legumes_Nuts_and_Seeds...
# Hummus                         L1_Dry_Beans_Peas_Other_Legumes_Nuts_and_Seeds...
# Pork and beans                 L1_Dry_Beans_Peas_Other_Legumes_Nuts_and_Seeds...
# Refried beans                  L1_Dry_Beans_Peas_Other_Legumes_Nuts_and_Seeds...
#
# [5 rows x 35 columns]
# === micro_avg_counts ===
# (226, 34)
#                                                     MCTs01  MCTs03  MCTs04  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    2455    2977    2796
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     984     704     312
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    1272     841      91
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0       1       1
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     577       1      13
#
#                                                     MCTs05  MCTs06  MCTs07  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    4394    1701    2682
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     918    1328     895
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     901     374     373
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0     133       0
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0      22     423
#
#                                                     MCTs08  MCTs09  MCTs10  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    3861    2507    1604
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     361     738     632
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     984     990     317
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       1       0       0
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       5     289     864
#
#                                                     MCTs11  ...  MCTs27  \
# #taxonomy                                                   ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    2562  ...    2135
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     385  ...    1019
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     324  ...     834
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       2  ...       0
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     515  ...     494
#
#                                                     MCTs28  MCTs29  MCTs31  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    1927    1243    1305
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     723    1151     285
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     214     320      12
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       7       1    4475
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     764     212       3
#
#                                                     MCTs32  MCTs33  MCTs34  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    1907    2463     914
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...    1183     263     308
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     150     274      15
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     643       0       0
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      26    1277    1592
#
#                                                     MCTs35  MCTs36  MCTs37
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     228    2890    4014
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     862    1281      11
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      25     596     760
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...    5383       2       1
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       3     494       6
#
# [5 rows x 34 columns]
# === micro_avg_clr ===
# (226, 34)
#                                                       MCTs01    MCTs03  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.859290  7.201650
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.944961  5.759780
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.201869  5.937664
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -2.100657 -1.038156
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.411600 -0.722071
#
#                                                       MCTs04    MCTs05  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  7.286964  8.508121
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.092335  6.942869
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  3.865590  6.923840
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -0.832760 -1.821913
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  1.899064 -1.271867
#
#                                                       MCTs06    MCTs07  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.803368  6.940060
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.556138  5.842153
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  4.289323  4.968064
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  3.255498 -1.890571
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  1.466751  5.093636
#
#                                                       MCTs08    MCTs09  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  8.125198  7.103329
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.755490  5.880035
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.757669  6.174391
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -0.215203 -1.746355
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  1.408860  4.944532
#
#                                                       MCTs10    MCTs11  ...  \
# #taxonomy                                                               ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.374835  6.963533  ...
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.443807  5.068783  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  4.752864  4.897182  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -1.783414 -0.159758  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.756158  5.359998  ...
#
#                                                       MCTs27    MCTs28  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.818469  6.050031
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  6.079311  5.069155
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.878493  3.853207
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -2.564737  0.438480
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.354885  5.125318
#
#                                                       MCTs29    MCTs31  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.610438  6.764241
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.533292  5.242155
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  4.253493  2.111757
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -1.388061  7.996331
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  3.842102  0.653496
#
#                                                       MCTs32    MCTs33  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.063266  6.962960
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.586363  4.725316
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  3.518468  4.767557
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  4.976432 -2.175202
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  1.769018  6.305741
#
#                                                       MCTs34    MCTs35  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.275426  4.837617
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  5.186338  6.168417
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  2.165220  2.612220
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__... -1.696088  7.999746
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  6.830803  0.515118
#
#                                                       MCTs36    MCTs37
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  7.262665  8.649655
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  6.448922  2.722394
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.684177  6.985696
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.143072  0.432303
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  5.495374  2.173593
#
# [5 rows x 34 columns]
# === micro_avg_norm ===
# (226, 34)
#                                                       MCTs01    MCTs03  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.245525  0.297746
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.098403  0.070412
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.127228  0.084121
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000032  0.000079
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.057726  0.000108
#
#                                                       MCTs04    MCTs05  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.279639  0.439380
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.031152  0.091846
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.009135  0.090115
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000083  0.000014
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.001278  0.000025
#
#                                                       MCTs06    MCTs07  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.170072  0.268209
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.132820  0.089466
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.037419  0.037329
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.013308  0.000039
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.002225  0.042323
#
#                                                       MCTs08    MCTs09  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.386106  0.250673
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.036104  0.073763
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.098355  0.099009
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000092  0.000036
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000468  0.028944
#
#                                                       MCTs10    MCTs11  ...  \
# #taxonomy                                                               ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.160434  0.256223  ...
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.063235  0.038525  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.031687  0.032450  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000046  0.000207  ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.086419  0.051548  ...
#
#                                                       MCTs27    MCTs28  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.213463  0.192738
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.101932  0.072273
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.083386  0.021424
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000018  0.000705
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.049396  0.076449
#
#                                                       MCTs29    MCTs31  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.124327  0.130526
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.115096  0.028488
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.032007  0.001245
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000114  0.447494
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.021212  0.000290
#
#                                                       MCTs32    MCTs33  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.190651  0.246305
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.118337  0.026283
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.014964  0.027417
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.064303  0.000026
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.002602  0.127658
#
#                                                       MCTs34    MCTs35  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.091381  0.022789
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.030752  0.086234
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.001499  0.002462
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000032  0.538287
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.159240  0.000302
#
#                                                       MCTs36    MCTs37
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.288962  0.401411
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.128067  0.001070
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.059609  0.076022
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000234  0.000108
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.049353  0.000618
#
# [5 rows x 34 columns]
# Done! CSV files were saved.

# %% [markdown]
# # Profiling the Paper 1 Gut Microbiome Abundance Dataset

# %%
import pandas as pd
import numpy as np

microbiome = pd.read_csv("microbiome.csv", index_col=0)

print("Shape:", microbiome.shape)
print("Number of microbial features:", microbiome.shape[0])
print("Number of samples:", microbiome.shape[1])

print("\nFirst rows:")
display(microbiome.head())

print("\nBasic statistics:")
display(microbiome.describe())
# Out:
# Shape: (223, 483)
# Number of microbial features: 223
# Number of samples: 483
#
# First rows:
#                                                     MCT.f.0002  MCT.f.0003  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       79055       33364
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        2421       16944
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       39779        9983
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           1           5
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       18393         561
#
#                                                     MCT.f.0004  MCT.f.0005  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       64027       70720
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       43511       18335
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       31539       44880
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           4           4
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       11742       15831
#
#                                                     MCT.f.0006  MCT.f.0007  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       63361       58636
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       36493       43987
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       29901       31975
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           7           2
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       14319       16541
#
#                                                     MCT.f.0008  MCT.f.0009  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       73520       69225
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       15944       20583
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       41607       39981
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...          13           3
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...        8328       10082
#
#                                                     MCT.f.0010  MCT.f.0011  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       58080       75592
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        5493       23064
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       32774       41183
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           9           4
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       40723       16670
#
#                                                     ...  MCT.f.0618  \
# #taxonomy                                           ...
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...      116037
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  ...          11
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...       25278
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...           7
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  ...          11
#
#                                                     MCT.f.0619  MCT.f.0620  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       93723      105413
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...          62           3
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       26608       24590
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...          10           1
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...          52           6
#
#                                                     MCT.f.0621  MCT.f.0622  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      100387       97278
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...           5          23
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       26421       24128
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           0         184
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           9          13
#
#                                                     MCT.f.0623  MCT.f.0624  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...      117400      123705
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...           2           7
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       23532       20010
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           2           2
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           5          10
#
#                                                     MCT.f.0625  MCT.f.0627  \
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       96470      117867
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...          18        2206
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       22195        9340
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           6         142
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           9        1246
#
#                                                     MCT.f.0628
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       93290
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...           5
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       21397
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           1
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...           4
#
# [5 rows x 483 columns]
# Basic statistics:
#          MCT.f.0002    MCT.f.0003    MCT.f.0004    MCT.f.0005    MCT.f.0006  \
# count    223.000000    223.000000    223.000000    223.000000    223.000000
# mean    1196.116592   1196.130045   1196.143498   1196.085202   1196.107623
# std     6292.628430   3929.367321   5764.614294   6018.009459   5532.632866
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       11.000000     13.000000     18.000000     15.000000     18.000000
# 50%       40.000000     91.000000     53.000000     57.000000     62.000000
# 75%      145.500000    429.000000    231.500000    267.000000    224.500000
# max    79055.000000  33364.000000  64027.000000  70720.000000  63361.000000
#
#          MCT.f.0007    MCT.f.0008    MCT.f.0009    MCT.f.0010    MCT.f.0011  \
# count    223.000000    223.000000    223.000000    223.000000    223.000000
# mean    1196.098655   1196.098655   1196.121076   1196.116592   1196.076233
# std     5599.856620   5909.878262   5687.239997   5478.451081   6156.212415
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       16.000000     18.000000     21.000000     12.000000     13.500000
# 50%       53.000000     56.000000     55.000000     46.000000     44.000000
# 75%      221.000000    285.000000    272.500000    141.500000    162.500000
# max    58636.000000  73520.000000  69225.000000  58080.000000  75592.000000
#
#        ...     MCT.f.0618    MCT.f.0619     MCT.f.0620     MCT.f.0621  \
# count  ...     223.000000    223.000000     223.000000     223.000000
# mean   ...    1196.085202   1196.107623    1196.125561    1196.134529
# std    ...    9425.191368   9155.216598    9278.133530    8784.064237
# min    ...       0.000000      0.000000       0.000000       0.000000
# 25%    ...       1.000000      0.000000       1.000000       0.000000
# 50%    ...       8.000000     10.000000       6.000000       7.000000
# 75%    ...      63.500000     77.500000      87.500000      85.500000
# max    ...  116037.000000  96191.000000  105413.000000  100387.000000
#
#          MCT.f.0622     MCT.f.0623     MCT.f.0624    MCT.f.0625  \
# count    223.000000     223.000000     223.000000    223.000000
# mean    1196.161435    1196.071749    1196.139013   1196.147982
# std     9080.516936    9225.165606    9218.804988   8983.242874
# min        0.000000       0.000000       0.000000      0.000000
# 25%        1.000000       0.000000       1.000000      2.000000
# 50%        9.000000       7.000000       8.000000     11.000000
# 75%       76.000000      70.000000      85.500000     80.000000
# max    97278.000000  117400.000000  123705.000000  96470.000000
#
#           MCT.f.0627     MCT.f.0628
# count     223.000000     223.000000
# mean     1196.107623    1196.076233
# std      8727.492092    9334.324673
# min         0.000000       0.000000
# 25%         7.000000       1.000000
# 50%        31.000000       6.000000
# 75%       174.500000      70.500000
# max    117867.000000  101379.000000
#
# [8 rows x 483 columns]

# %% [markdown]
# EDA on microbiome data from the Johnson et al. 2019 research

# %% [markdown]
# ## Gut Microbiome Data Profiling
#
# In this step, we loaded the gut microbiome abundance table (`microbiome.csv`) generated from the Johnson et al. 2019 dataset.
#
# We performed an initial profiling of the dataset to better understand its structure and characteristics before preprocessing and filtering.
#
# ### What we examined
# - Dataset dimensions
# - Number of microbial features (taxa/species)
# - Number of samples
# - First rows of the abundance table
# - Descriptive statistics for abundance values
#
# ### Results
# - The dataset contains:
#   - **223 microbial features**
#   - **483 fecal samples**
# - Rows represent microbial taxa/species.
# - Columns represent individual microbiome samples.
# - The abundance values are highly variable across samples, with many low values and zeros, which is common in microbiome datasets.
#
# ### Key observations
# - Some bacterial species are highly abundant in specific samples.
# - Many taxa appear at very low abundance levels.
# - The dataset is expected to be sparse, meaning many entries contain zeros due to absent or rare microbes.
#
# This profiling step provides the foundation for the next stages:
# 1. Low-prevalence feature filtering
# 2. Sparsity analysis
# 3. Data preprocessing for downstream microbiome analysis

# %% [markdown]
# # Analyzing Sparsity and Feature Prevalence

# %%
# Calculate sparsity (percentage of zeros)

total_values = microbiome.size
zero_values = (microbiome == 0).sum().sum()

sparsity = (zero_values / total_values) * 100

print("Total values in dataset:", total_values)
print("Number of zero values:", zero_values)
print(f"Sparsity: {sparsity:.2f}%")
# Out:
# Total values in dataset: 107709
# Number of zero values: 9467
# Sparsity: 8.79%

# %%
# Prevalence of each microbial feature
# (fraction of samples where feature appears)

prevalence = (microbiome > 0).sum(axis=1) / microbiome.shape[1]

print(prevalence.describe())

# Show first prevalence values
display(prevalence.head())
# Out:
# count    223.000000
# mean       0.912106
# std        0.145638
# min        0.271222
# 25%        0.910973
# 50%        0.973085
# 75%        0.994824
# max        1.000000
# dtype: float64
# #taxonomy
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;NA                                   1.000000
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Faecalibacterium;s__Faecalibacterium prausnitzii    1.000000
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__Bacteroides uniformis             1.000000
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Prevotella;s__Prevotella copri                   0.910973
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Rikenellaceae;g__Alistipes;s__Alistipes putredinis                 0.993789
# dtype: float64

# %% [markdown]
# ## Sparsity and Prevalence Analysis
#
# In this step, we analyzed the sparsity and prevalence of the gut microbiome abundance table.
#
# ### Sparsity Analysis
# We calculated the percentage of zero values in the dataset to measure sparsity.
#
# ### Results
# - Total values in the dataset: **107,709**
# - Zero values: **9,467**
# - Dataset sparsity: **8.79%**
#
# This indicates that most microbial features are present in many samples, while a smaller portion of the matrix contains absent microbes (zeros).
#
# ### Prevalence Analysis
# We then calculated the prevalence of each microbial feature, defined as the fraction of samples in which a feature appears.
#
# ### Key observations
# - The average prevalence across taxa is very high (~0.91).
# - Many microbial species appear in nearly all samples.
# - Some taxa are less common and appear only in a subset of participants.
# - The minimum prevalence observed was approximately **27%** of samples.
#
# These results suggest that the dataset is relatively dense compared to many microbiome datasets, but still contains lower-prevalence taxa that may be filtered in the next preprocessing stage.

# %% [markdown]
# # Filtering Low-Prevalence Microbial Features

# %%
# Filter low-prevalence microbial features

threshold = 0.10   # keep taxa appearing in at least 10% of samples

filtered_microbiome = microbiome.loc[prevalence >= threshold]

print("Original shape:", microbiome.shape)
print("Filtered shape:", filtered_microbiome.shape)

print("Removed features:", microbiome.shape[0] - filtered_microbiome.shape[0])
# Out:
# Original shape: (223, 483)
# Filtered shape: (223, 483)
# Removed features: 0

# %%
filtered_microbiome.to_csv("microbiome_filtered.csv")

print("Filtered microbiome dataset saved.")
# Out:
# Filtered microbiome dataset saved.

# %%
import pandas as pd
import os

"""
paper2_data.py
Loads and exports datasets from Carlino et al. 2024 (Cell)
Source: https://github.com/SegataLab/cFMD
"""

# Base link to database
#base_cfmd = "cFMD/cFMD_data"
base_cfmd = r"data\cFMD-main\cFMD-main\cFMD_data"

# Dataset of microbial species  vs fecal samples
data_base = []
# Iterate on each dataset in the database
for dataset in os.listdir(base_cfmd):
    # Create path to dataset
    path = os.path.join(base_cfmd, dataset, f"{dataset}_taxonomic_profiles.tsv")
    # If the path is correct add the dataset to the data base
    if os.path.exists(path):
        df = pd.read_csv(path, sep="\t", index_col=0)
        data_base.append(df)

# Join the data sets to one single data set
combined = pd.concat(data_base, axis=1)
# Fill null value with zero
combined = combined.fillna(0)
print("Shape:", combined.shape)

# save the combined datasets to csv
combined.to_csv("combined_datasets.csv")

# Metadata on the microbiome
#metadata = pd.read_csv("cFMD/cFMD_metadata.tsv", sep="\t")
metadata = pd.read_csv("data/cFMD-main/cFMD-main/cFMD_metadata.tsv", sep="\t")
# Export the metadata to csv
metadata.to_csv("cfmd_metadata.csv", index=False)
# Out:
# Shape: (5057, 3393)

# %%
import os

#for item in os.listdir(r"C:\Users\rtajz\Downloads"):
for item in os.listdir(r"data"):
    if "cFMD" in item or "cfmd" in item:
        print(item)
# Out:
# cFMD-main
# cfmd_metadata.csv

# %% [markdown]
# # Loading and Combining the Paper 2 (cFMD) Microbiome Dataset

# %%
import pandas as pd
import os

# Paper 2: Carlino et al. 2024 / cFMD dataset
#base_cfmd = r"C:\Users\rtajz\Downloads\cFMD-main\cFMD-main\cFMD_data"
#metadata_path = r"C:\Users\rtajz\Downloads\cFMD-main\cFMD-main\cFMD_metadata.tsv"
base_cfmd = r"data\cFMD-main\cFMD-main\cFMD_data"
metadata_path = r"data\cFMD-main\cFMD-main\cFMD_metadata.tsv"#

print("Base exists:", os.path.exists(base_cfmd))
print("Metadata exists:", os.path.exists(metadata_path))

data_base = []

for dataset in os.listdir(base_cfmd):
    path = os.path.join(base_cfmd, dataset, f"{dataset}_taxonomic_profiles.tsv")
    
    if os.path.exists(path):
        df = pd.read_csv(path, sep="\t", index_col=0)
        data_base.append(df)

combined = pd.concat(data_base, axis=1)
combined = combined.fillna(0)

print("=== Paper 2 combined dataset ===")
print("Shape:", combined.shape)
display(combined.head())

combined.to_csv("combined_datasets.csv")

metadata = pd.read_csv(metadata_path, sep="\t")

print("=== Paper 2 metadata ===")
print("Shape:", metadata.shape)
display(metadata.head())

metadata.to_csv("cfmd_metadata.csv", index=False)

print("Done! Paper 2 CSV files were saved.")
# Out:
# Base exists: False
# Metadata exists: False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[180], line 13
#       9 print("Metadata exists:", os.path.exists(metadata_path))
#      11 data_base = []
# ---> 13 for dataset in os.listdir(base_cfmd):
#      14     path = os.path.join(base_cfmd, dataset, f"{dataset}_taxonomic_profiles.tsv")
#      16     if os.path.exists(path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\rtajz\\Downloads\\cFMD-main\\cFMD-main\\cFMD_data'

# %% [markdown]
# ## Paper 2 Dataset Integration and Exploration
#
# In this step, we loaded and combined multiple microbiome datasets from the cFMD database (Carlino et al. 2024).
#
# ### What was done
# - Loaded all taxonomic profile tables from the cFMD repository.
# - Merged all datasets into one combined abundance matrix.
# - Filled missing values with zeros.
# - Loaded and explored the accompanying metadata table.
# - Exported both the combined microbiome dataset and metadata to CSV files.
#
# ### Results
# - Combined microbiome dataset shape:
#   - **5057 microbial features**
#   - **3393 samples**
# - Metadata table shape:
#   - **3444 samples**
#   - **32 metadata variables**
#
# ### Key observations
# - The combined dataset contains thousands of microbial taxa collected from many food-related microbiome samples.
# - Missing values were replaced with zeros to create a complete abundance matrix for downstream analysis.
# - The metadata includes detailed information such as:
#   - dataset source
#   - food category
#   - fermentation status
#   - country
#   - sequencing information
#
# This integrated dataset will be used for profiling, sparsity analysis, prevalence filtering, and food microbiome exposure analysis in later stages of the project.

# %% [markdown]
# # Profiling the Paper 2 Food Microbiome Dataset

# %%
import pandas as pd
import numpy as np

combined = pd.read_csv("combined_datasets.csv", index_col=0)

print("Shape:", combined.shape)
print("Number of microbial features:", combined.shape[0])
print("Number of samples:", combined.shape[1])

print("\nFirst rows:")
display(combined.head())

print("\nBasic statistics:")
display(combined.describe())
# Out:
# C:\Users\rtajz\AppData\Local\Temp\ipykernel_6276\1864880361.py:4: DtypeWarning: Columns (823) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined = pd.read_csv("combined_datasets.csv", index_col=0)
# Shape: (5057, 3393)
# Number of microbial features: 5057
# Number of samples: 3393
#
# First rows:
#                                                     AlmeidaO_2020__SRR8742576  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.14109
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.10390
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00000
#
#                                                     AlmeidaO_2020__SRR8742577  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                        0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                        0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                        0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                        0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                        0.0
#
#                                                     AlmeidaO_2020__SRR8742578  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.40403
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.08975
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00000
#
#                                                     AlmeidaO_2020__SRR8742579  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.62919
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00000
#
#                                                     AlmeidaO_2020__SRR8742580  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.24468
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00000
#
#                                                     AlmeidaO_2020__SRR8742581  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00653
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00000
#
#                                                     AlmeidaO_2020__SRR8742582  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.08219
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00000
#
#                                                     AlmeidaO_2020__SRR8742584  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                        0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                        0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                        0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                        0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                        0.0
#
#                                                     AlmeidaO_2020__SRR8742585  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00000
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                    0.00553
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                    0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                    0.00236
#
#                                                     AlvarezOrdonezA_xxxx__C01-19  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                           0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                           0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                           0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                           0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                           0.0
#
#                                                     ...  \
# sample                                              ...
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...  ...
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...  ...
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...  ...
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...  ...
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...  ...
#
#                                                     YuY_2022__SRR16950700  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                9.44002
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...               51.21205
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                0.00000
#
#                                                     YuY_2022__SRR16950701  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                9.00307
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...               52.55470
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                0.00000
#
#                                                     YuY_2022__SRR16950702  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                0.02590
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                0.00084
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                0.12650
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                0.00000
#
#                                                     YuY_2022__SRR16950703  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                0.02644
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                0.13905
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                0.00000
#
#                                                     YuY_2022__SRR16950704  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                0.01921
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                0.12204
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                0.00000
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                0.00000
#
#                                                     ZhaoCC_2020__SRS5803191  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                      0.0
#
#                                                     ZhaoCC_2020__SRS5803192  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                      0.0
#
#                                                     ZhaoCC_2020__SRS5803193  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                      0.0
#
#                                                     ZhaoCC_2020__SRS5803194  \
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                      0.0
#
#                                                     ZhaoCC_2020__SRS5803195
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...                      0.0
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobac...                      0.0
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacilla...                      0.0
#
# [5 rows x 3393 columns]
# Basic statistics:
#        AlmeidaO_2020__SRR8742576  AlmeidaO_2020__SRR8742577  \
# count                5057.000000                5057.000000
# mean                    0.019775                   0.019775
# std                     0.464130                   0.809432
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    14.899330                  50.947280
#
#        AlmeidaO_2020__SRR8742578  AlmeidaO_2020__SRR8742579  \
# count                5057.000000                5057.000000
# mean                    0.019775                   0.019775
# std                     0.702070                   1.000120
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    34.887790                  68.751090
#
#        AlmeidaO_2020__SRR8742580  AlmeidaO_2020__SRR8742581  \
# count                5057.000000                5057.000000
# mean                    0.019775                   0.019775
# std                     0.823940                   1.377910
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    45.144070                  97.984570
#
#        AlmeidaO_2020__SRR8742582  AlmeidaO_2020__SRR8742584  \
# count                5057.000000                5057.000000
# mean                    0.019775                   0.019775
# std                     1.207965                   1.222904
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    85.627740                  86.723460
#
#        AlmeidaO_2020__SRR8742585  AlvarezOrdonezA_xxxx__C01-19  ...  \
# count                5057.000000                   5057.000000  ...
# mean                    0.019775                      0.019775  ...
# std                     0.989689                      1.378808  ...
# min                     0.000000                      0.000000  ...
# 25%                     0.000000                      0.000000  ...
# 50%                     0.000000                      0.000000  ...
# 75%                     0.000000                      0.000000  ...
# max                    68.564110                     98.031220  ...
#
#        YuY_2022__SRR16950700  YuY_2022__SRR16950701  YuY_2022__SRR16950702  \
# count            5057.000000            5057.000000            5057.000000
# mean                0.019775               0.019775               0.019775
# std                 0.790612               0.804994               0.589352
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               0.000000
# 75%                 0.000000               0.000000               0.000000
# max                51.212050              52.554700              31.997520
#
#        YuY_2022__SRR16950703  YuY_2022__SRR16950704  ZhaoCC_2020__SRS5803191  \
# count            5057.000000            5057.000000              5057.000000
# mean                0.019775               0.019775                 0.019775
# std                 0.590576               0.609805                 1.001798
# min                 0.000000               0.000000                 0.000000
# 25%                 0.000000               0.000000                 0.000000
# 50%                 0.000000               0.000000                 0.000000
# 75%                 0.000000               0.000000                 0.000000
# max                32.200410              35.128140                67.891230
#
#        ZhaoCC_2020__SRS5803192  ZhaoCC_2020__SRS5803193  \
# count              5057.000000              5057.000000
# mean                  0.019775                 0.019775
# std                   1.018110                 1.352622
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                  69.383600                96.157660
#
#        ZhaoCC_2020__SRS5803194  ZhaoCC_2020__SRS5803195
# count              5057.000000              5057.000000
# mean                  0.019775                 0.019775
# std                   0.754040                 0.738988
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                  44.609890                49.369390
#
# [8 rows x 3392 columns]

# %% [markdown]
# ## Profiling the Paper 2 Food Microbiome Dataset
#
# In this step, we performed an initial exploration and profiling of the combined cFMD microbiome abundance dataset.
#
# ### What was examined
# - Dataset dimensions
# - Number of microbial features
# - Number of samples
# - First rows of the abundance matrix
# - Descriptive statistics of microbial abundance values
#
# ### Results
# - The dataset contains:
#   - **5057 microbial features**
#   - **3393 microbiome samples**
# - Rows represent microbial taxa/species.
# - Columns represent individual food microbiome samples collected from multiple datasets.
#
# ### Key observations
# - The dataset is substantially larger than the Paper 1 microbiome dataset.
# - Many abundance values are very small or zero, indicating the presence of rare microbial taxa.
# - The abundance distributions are highly skewed, which is common in microbiome sequencing data.
# - Some microbial taxa appear frequently across samples, while others are highly sparse.
#
# This profiling step provides the basis for further preprocessing, including sparsity analysis, prevalence filtering, and downstream microbiome exposure analysis.

# %% [markdown]
# # Sparsity and Prevalence Analysis of the Paper 2 Dataset

# %%
# Calculate sparsity

total_values = combined.size
zero_values = (combined == 0).sum().sum()

sparsity = (zero_values / total_values) * 100

print("Total values in dataset:", total_values)
print("Number of zero values:", zero_values)
print(f"Sparsity: {sparsity:.2f}%")
# Out:
# Total values in dataset: 17158401
# Number of zero values: 17063753
# Sparsity: 99.45%

# %%
# Convert all values to numeric
combined_numeric = combined.apply(pd.to_numeric, errors='coerce')

# Replace NaN with zero
combined_numeric = combined_numeric.fillna(0)

# Calculate prevalence
prevalence = (combined_numeric > 0).sum(axis=1) / combined_numeric.shape[1]

print(prevalence.describe())

display(prevalence.head())
# Out:
# count    5057.000000
# mean        0.005502
# std         0.021082
# min         0.000000
# 25%         0.000295
# 50%         0.000884
# 75%         0.002653
# max         0.561745
# dtype: float64
# sample
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Streptococcaceae|g__Lactococcus|s__Lactococcus_lactis|t__SGB7985                          0.561745
# k__Bacteria|p__Actinomycetota|c__Actinomycetes|o__Propionibacteriales|f__Propionibacteriaceae|g__Cutibacterium|s__Cutibacterium_acnes|t__SGB16955    0.071913
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Lactobacillaceae|g__Lactiplantibacillus|s__Lactiplantibacillus_plantarum|t__SGB7202       0.181256
# k__Bacteria|p__Pseudomonadota|c__Gammaproteobacteria|o__Enterobacterales|f__Erwiniaceae|g__Pantoea|s__Pantoea_coffeiphila|t__SGB23192                0.007073
# k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacillales|f__Paenibacillaceae|g__Paenibacillus|s__Paenibacillus_cookii|t__SGB7404                           0.003831
# dtype: float64

# %% [markdown]
# ### Prevalence Analysis of the Paper 2 Dataset
#
# We analyzed the prevalence of microbial features in the Paper 2 microbiome dataset after converting all values to numeric format. Since the dataset originally contained mixed data types, non-numeric values were converted to `NaN` and then replaced with zeros to enable numerical analysis.
#
# The prevalence calculation measured the fraction of samples in which each microbial feature appeared (abundance > 0).
#
# The results show that the dataset is highly sparse:
# - The average prevalence is very low (~0.0055).
# - Many microbial taxa appear in only a very small number of samples.
# - Some taxa are present in more samples, with the maximum prevalence reaching ~56%.
#
# These findings are consistent with large-scale microbiome datasets, where most microbial species are rare and only a subset are commonly observed across samples.
